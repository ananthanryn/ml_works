# %%
import tensorflow as tf
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input, decode_predictions
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
model = InceptionV3(weights='imagenet')

# %%
img_path = 'datasets/elephant.jpg'
img = image.load_img(img_path, target_size=(299, 299))
plt.imshow(np.asarray(img))

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
prediction = model.predict(x)

# %%
print('Predicted:', decode_predictions(prediction, top=3)[0])
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 1us/step
# Predicted: [('n02504458', 'African_elephant', 0.5665001), ('n01871265', 'tusker', 0.41925827), ('n02504013', 'Indian_elephant', 0.0007726949)]

# %%
img_path = 'datasets/soccer_ball.jpg'
img = image.load_img(img_path, target_size=(299, 299))
plt.imshow(np.asarray(img))

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
prediction = model.predict(x)

# %%
print('Predicted:', decode_predictions(prediction, top=3)[0])
# Out:
# Predicted: [('n04254680', 'soccer_ball', 0.9999956), ('n04540053', 'volleyball', 8.038737e-07), ('n02097658', 'silky_terrier', 1.8536322e-07)]
